# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/HRDataset_v14.csv')
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
x=len(df['Position'] .unique().tolist())
print(x)
y=len(df['MaritalDesc'] .unique().tolist())
print(y)
z=len(df['CitizenDesc'] .unique().tolist())
print(z)
m=len(df['TermReason'] .unique().tolist())
print(m)
n=len(df['EmploymentStatus'] .unique().tolist())
print(n)

t=len(df['Department'] .unique().tolist())
print(t)
s=len(df['RecruitmentSource'] .unique().tolist())
print(s)
o=len(df['PerformanceScore'] .unique().tolist())
print(o)
# Out:
# 32
# 5
# 3
# 18
# 3
# 6
# 9
# 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x='EngagementSurvey',y='Salary',data=df)
plt.show()

# %%
sns.relplot(x='EngagementSurvey',y='Salary',data=df,hue='Sex')

# %%
sns.relplot(x='EngagementSurvey',y='Salary',data=df,hue='MaritalDesc')

# %%
sns.relplot(x='EngagementSurvey',y='Salary',data=df,hue='EmploymentStatus')

# %%
sns.relplot(x='EngagementSurvey',y='Salary',data=df,hue='Department')

# %%
sns.relplot(x='EngagementSurvey',y='Salary',data=df,col='Sex', hue='MaritalDesc')

# %%
fig = plt.figure(figsize=(8,5))
g = sns.distplot(df.Salary)
g.set_title('Salary distribution');
# Out:
# <ipython-input-37-b41cd549a277>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   g = sns.distplot(df.Salary)

# %%
fig = plt.figure(figsize=(8,5))
g = sns.catplot(x="EmpSatisfaction",y="Salary",kind='swarm',ci=False,data=df)
g.fig.suptitle('Salary by employee satisfaction [Swarm Plot]',y=1.05)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 11.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 11.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0.5, 1.05, 'Salary by employee satisfaction [Swarm Plot]')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import matplotlib.pyplot as plt
grouped=df.groupby(['Sex']).count()
fig=plt.figure()
ax=fig.add_axes([0.1,0.2,0.8,0.9])
ax.bar(grouped.index,grouped['EmpID'], color='green')
ax.set_xlabel('Sex')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
grouped=df.groupby(['MaritalDesc']).count()
fig=plt.figure()
ax=fig.add_axes([0.1,0.2,0.8,0.9])
ax.bar(grouped.index,grouped['EmpID'],color='purple')
ax.set_xlabel('Marital Status')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
grouped=df.groupby(['Department']).count()
fig=plt.figure()
ax=fig.add_axes([0.1,0.2,0.8,0.9])
ax.bar(grouped.index,grouped['EmpID'],color='blue')
ax.set_xlabel('Department')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
grouped=df.groupby(['PerformanceScore']).count()
fig=plt.figure()
ax=fig.add_axes([0.1,0.2,0.8,0.9])
ax.bar(grouped.index,grouped['EmpID'],color='orange')
ax.set_xlabel('PerformanceScore')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
grouped=df.groupby(['RecruitmentSource']).count()
fig=plt.figure()
ax=fig.add_axes([0.1,0.2,0.8,0.9])
ax.barh(grouped.index,grouped['EmpID'],color='pink')
ax.set_xlabel('Recruitment Source')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
grouped=df.groupby(['Position']).count()
fig=plt.figure()
ax=fig.add_axes([0.1,0.2,0.8,0.9])
ax.barh(grouped.index,grouped['EmpID'],color='olive')
ax.set_xlabel('Position')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
key='Sex'
col='green'
grouped2=df.groupby([key]).mean()
fig, ax=plt.subplots(nrows=2, ncols=2)
ax[0,0].bar(grouped2.index,grouped2['Salary'],color=col,hatch='/')
ax[0,0].set_ylabel('Average salary')
ax[0,1].bar(grouped2.index,grouped2['EngagementSurvey'],color=col,hatch='o')
ax[0,1].set_ylabel('Average engagement survey')
ax[1,0].bar(grouped2.index,grouped2['EmpSatisfaction'],color=col,hatch='+')
ax[1,0].set_ylabel('Average employee satisfaction')
ax[1,1].bar(grouped2.index,grouped2['Absences'],color=col,hatch='*')
ax[1,1].set_ylabel('Average absences')
fig.suptitle('Under different sex')
# Out:
# <ipython-input-73-f24f6338f72c>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped2=df.groupby([key]).mean()
# Text(0.5, 0.98, 'Under different sex')

# %%
key='MaritalDesc'
col='purple'
grouped2=df.groupby([key]).mean()
fig, ax=plt.subplots(nrows=2, ncols=2)
ax[0,0].barh(grouped2.index,grouped2['Salary'],color=col,hatch='/')
ax[0,0].set_ylabel('Average salary')
ax[0,1].barh(grouped2.index,grouped2['EngagementSurvey'],color=col,hatch='o')
ax[0,1].set_ylabel('Average engagement survey')
ax[0,1].yaxis.set_label_position("right")
ax[0,1].yaxis.tick_right()
ax[1,0].barh(grouped2.index,grouped2['EmpSatisfaction'],color=col,hatch='+')
ax[1,0].set_ylabel('Average employee satisfaction')
ax[1,1].barh(grouped2.index,grouped2['Absences'],color=col,hatch='*')
ax[1,1].set_ylabel('Average absences')
ax[1,1].yaxis.set_label_position("right")
ax[1,1].yaxis.tick_right()
fig.suptitle('Under different marital status')
# Out:
# <ipython-input-86-b650f34c3f3f>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped2=df.groupby([key]).mean()
# Text(0.5, 0.98, 'Under different marital status')

# %%
key='Department'
col='blue'
grouped2=df.groupby([key]).mean()
fig, ax=plt.subplots(nrows=2, ncols=2)
ax[0,0].barh(grouped2.index,grouped2['Salary'],color=col,hatch='/')
ax[0,0].set_ylabel('Average salary')
ax[0,1].barh(grouped2.index,grouped2['EngagementSurvey'],color=col,hatch='o')
ax[0,1].set_ylabel('Average engagement survey')
ax[0,1].yaxis.set_label_position("right")
ax[0,1].yaxis.tick_right()
ax[1,0].barh(grouped2.index,grouped2['EmpSatisfaction'],color=col,hatch='+')
ax[1,0].set_ylabel('Average employee satisfaction')
ax[1,1].barh(grouped2.index,grouped2['Absences'],color=col,hatch='*')
ax[1,1].set_ylabel('Average absences')
ax[1,1].yaxis.set_label_position("right")
ax[1,1].yaxis.tick_right()
fig.suptitle('Under different departments')
# Out:
# <ipython-input-85-4fcf6fccebce>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped2=df.groupby([key]).mean()
# Text(0.5, 0.98, 'Under different departments')

# %%
key='RecruitmentSource'
col='pink'
grouped2=df.groupby([key]).mean()
fig, ax=plt.subplots(nrows=2, ncols=2)
ax[0,0].barh(grouped2.index,grouped2['Salary'],color=col,hatch='/')
ax[0,0].set_ylabel('Average salary')
ax[0,1].barh(grouped2.index,grouped2['EngagementSurvey'],color=col,hatch='o')
ax[0,1].set_ylabel('Average engagement survey')
ax[0,1].yaxis.set_label_position("right")
ax[0,1].yaxis.tick_right()
ax[1,0].barh(grouped2.index,grouped2['EmpSatisfaction'],color=col,hatch='+')
ax[1,0].set_ylabel('Average employee satisfaction')
ax[1,1].barh(grouped2.index,grouped2['Absences'],color=col,hatch='*')
ax[1,1].set_ylabel('Average absences')
ax[1,1].yaxis.set_label_position("right")
ax[1,1].yaxis.tick_right()
fig.suptitle('Under different recruitment sources')
# Out:
# <ipython-input-84-67ce0738a372>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped2=df.groupby([key]).mean()
# Text(0.5, 0.98, 'Under different recruitment sources')
